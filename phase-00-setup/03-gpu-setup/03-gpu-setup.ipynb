# %% [markdown]
# <a href="https://colab.research.google.com/github/mavazvar95/ai-engineering-from-scratch/blob/main/phase-00-setup/03-gpu-setup/03-gpu-setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print(f"CUDA available: {torch.cuda.is_available()}")
print(f"PyTorch version: {torch.__version__}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    mem = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"VRAM: {mem:.1f} GB")
    print(f"Max model size (fp16 rule): ~{mem / 2:.0f}B parameters")
# Out:
# CUDA available: True
# PyTorch version: 2.11.0+cu128
# GPU: Tesla T4
# VRAM: 15.6 GB
# Max model size (fp16 rule): ~8B parameters

# %%
import time

size = 5000
a_cpu = torch.randn(size, size)
b_cpu = torch.randn(size, size)

# CPU
start = time.time()
c_cpu = a_cpu @ b_cpu
cpu_time = time.time() - start
print(f"CPU: {cpu_time:.3f}s")

# GPU
if torch.cuda.is_available():
    a_gpu = a_cpu.to("cuda")
    b_gpu = b_cpu.to("cuda")
    torch.cuda.synchronize()
    start = time.time()
    c_gpu = a_gpu @ b_gpu
    torch.cuda.synchronize()
    gpu_time = time.time() - start
    print(f"GPU: {gpu_time:.3f}s")
    print(f"Speedup: {cpu_time / gpu_time:.0f}x")
# Out:
# CPU: 2.035s
# GPU: 0.199s
# Speedup: 10x
